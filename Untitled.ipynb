# %%
from unidecode import unidecode

# %%
texts = """
Я ўсё жыццё шукаў адрэналіну.
Я пераканаўся, што мая каманда апынецца ў тройцы лепшых.
Мне не падабаецца, калі я вяртаюся дадому з паходу і адчуваю сябе бруднай.
Калі я злуюся, я магу быць крыху агрэсіўным.
Усе кажуць, што я павінен больш усміхацца.
Мае лідэрскія якасці вельмі добрыя, і я ведаў, што аднойчы стану менеджэрам.
"""

print(unidecode(texts))
# Out:
# Ia usio zhytstsio shukau adrenalinu.
# Ia perakanausia, shto maia kamanda apynetstsa u troitsy lepshykh.
# perakanalasia
# Mne ne padabaetstsa, kali ia viartaiusia dadomu z pakhodu i adchuvaiu siabe brudnai.
# Kali ia zluiusia, ia magu byts' krykhu agresiunym.
# Use kazhuts', shto ia pavinen bol'sh usmikhatstsa.
# Mae liderskiia iakastsi vel'mi dobryia, i ia vedau, shto adnoichy stanu menedzheram.

# %%
from parser import Parser


p = Parser('be')
p.dict['Мае лідэрскія якасці вельмі добрыя, і я ведаў, што аднойчы стану менеджэрам.']['sentences'][0]['tokens']
# Out:
# [{'id': 1,
#   'text': 'Мае',
#   'upos': 'DET',
#   'feats': 'Case=Nom|Degree=Pos|Number=Plur',
#   'head': 3,
#   'deprel': 'det',
#   'dspan': [0, 3],
#   'span': [0, 3]},
#  {'id': 2,
#   'text': 'лідэрскія',
#   'upos': 'ADJ',
#   'feats': 'Case=Nom|Degree=Pos|Number=Plur',
#   'head': 3,
#   'deprel': 'amod',
#   'dspan': [4, 13],
#   'span': [4, 13]},
#  {'id': 3,
#   'text': 'якасці',
#   'upos': 'NOUN',
#   'feats': 'Animacy=Inan|Case=Nom|Gender=Fem|Number=Plur',
#   'head': 5,
#   'deprel': 'nsubj',
#   'dspan': [14, 20],
#   'span': [14, 20]},
#  {'id': 4,
#   'text': 'вельмі',
#   'upos': 'ADV',
#   'xpos': 'RB',
#   'feats': 'Degree=Pos',
#   'head': 5,
#   'deprel': 'advmod',
#   'dspan': [21, 27],
#   'span': [21, 27]},
#  {'id': 5,
#   'text': 'добрыя',
#   'upos': 'ADJ',
#   'feats': 'Case=Nom|Degree=Pos|Number=Plur',
#   'head': 0,
#   'deprel': 'root',
#   'dspan': [28, 34],
#   'span': [28, 34]},
#  {'id': 6,
#   'text': ',',
#   'upos': 'PUNCT',
#   'head': 9,
# ...
